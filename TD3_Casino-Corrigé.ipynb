# %% [markdown]
# # TD 3: le casino
#
# Dans cette activité, nous allons simuler des jeux de hasard et estimer de probabilités d’obtenir différents résultats.
#
# ### Préliminaires : probabilités et simulation
# La notion de probabilité peut être vue comme une évaluation quantitative de l’incertitude entourant un fait ou un événement. Par exemple, si on lance un dé à six faces, on peut esti-mer a priori la probabilité d’obtenir le résultat « cinq » : une chance sur six, soit 0.17 environ. On peut aussi estimer la probabilité d’obtenir « au moins cinq » : cette fois la probabilité est d’environ une chance sur trois, puisque cet événement recouvre deux des résultats pos-sibles parmi six, et on suppose qu’ils ont tous les mêmes chances de se produire.
#
# Parfois, l’analyse des probabilités est plus difficile : supposons que je lance trois dés : quelle est la probabilité que les trois résultats soient égaux? Au lieu d’évaluer une telle probabilité de manière analytique, la programmation nous fournit une autre option intéressante : on peut simuler l’expérience de manière répétée, et compter combien de fois le résultat cherché se produit. Les lois des probabilités nous disent qu’à mesure que le nombre de répétitions augmente, la fréquence de l’événement (le nombre de fois qu’il se produit sur le nombre total d’expériences) va tendre vers la probabilité réelle.
#
# Par exemple, si on répète un million de fois l’expérience de lancer trois dés, et on compte combien de fois les trois sont égaux, on trouverait que ce résultat se produit environ 27000 fois, soit dans environ 2.7% des expériences. On en déduira donc que la probabilité d’obtenir trois fois la même valeur en lançant trois dés est d’environ 2.7%, ou 0.027.
#
# ## Tutoriel: trois dés égaux
#
# Dans le tutoriel, nous allons simuler l'expérience précédente: lancer trois dés, et évaluer la probabilité d'obtenir le même nombre sur les trois.
#
# On a vu dans le TD précédent que la bibliothèque ```random``` permettait de générer des nombres aléatoires. Pour simuler le lancer d'un dé à six faces, on va générer de façon équiprobable les nombres 1, 2, 3, 4, 5, ou 6.
# Pour ceci on importe la bibliothèque ```random``` et on choisit un entier dans l'intervalle \[1-6\]:

# %%
import random
random.randrange(1,7)
# Out:
# 6

# %% [markdown]
# Pour notre expérience, il faut lancer trois dés:

# %%
dé1 = random.randrange(1,7)
dé2 = random.randrange(1,7)
dé3 = random.randrange(1,7)
print("les trois dés affichent:", dé1, dé2, dé3)
# Out:
# les trois dés affichent: 5 5 4

# %% [markdown]
# On veut répéter cette expérience un grand nombre de fois, et compter combien de fois les trois dés sont égaux.
#
# Commençons par réfléchir à la répétition: ici on voudrait répéter l'expérience un million de fois. On va déjà écrie le code pour répéter l'expérience 10 fois, et ensuite on changera les chiffres pour le faire un million de fois.
#
# Dans tous les cas, on sait à l'avance combien de fois le contenu de la boucle doit se répéter, c'est donc une répétition _inconditionnelle_. On utilise donc une instruction répétitive ```for```, et pour obtenir 10 répétitions on utilise un objet ```range``` qui représente l'intervalle \[0-9\]:

# %%
for i in range(10):
    dé1 = random.randrange(1,7)
    dé2 = random.randrange(1,7)
    dé3 = random.randrange(1,7)
    print("les trois dés affichent:", dé1, dé2, dé3)
# Out:
# les trois dés affichent: 4 1 6
# les trois dés affichent: 2 1 6
# les trois dés affichent: 4 4 6
# les trois dés affichent: 4 3 6
# les trois dés affichent: 1 6 1
# les trois dés affichent: 3 3 2
# les trois dés affichent: 5 1 6
# les trois dés affichent: 2 4 3
# les trois dés affichent: 4 3 3
# les trois dés affichent: 6 3 3

# %% [markdown]
# On peut ajouter une ligne de code pour identifier le cas où les trois valeurs sont égales:

# %%
for i in range(10):
    dé1 = random.randrange(1,7)
    dé2 = random.randrange(1,7)
    dé3 = random.randrange(1,7)
    print("les trois dés affichent:", dé1, dé2, dé3)
    if(dé1==dé2 and dé2==dé3):
        print("les trois valeurs sont égales !")
# Out:
# les trois dés affichent: 6 6 6
# les trois valeurs sont égales !
# les trois dés affichent: 5 1 2
# les trois dés affichent: 1 4 1
# les trois dés affichent: 4 5 1
# les trois dés affichent: 6 3 4
# les trois dés affichent: 1 6 3
# les trois dés affichent: 2 6 3
# les trois dés affichent: 2 5 3
# les trois dés affichent: 3 3 5
# les trois dés affichent: 5 3 6

# %% [markdown]
# Maintenant on va _compter_ le nombre d'expériences où les trois dés ont donné la même valeur. Pour _compter_ les occurences d'un certain événement durant un processus répétitif, il y a une "recette" très simple: on utilise une variable dite "accumulateur", qu'on initialise à zéro avant la boucle. Ensuite, à l'intérieur de la boucle, chaque fois qu'on rencontre l'événement, on incrémente l'accumulateur (c'est-à-dire qu'on y ajoute 1). La structure du code est donc la suivante:
# ```
# compte = 0 #accumulateur initialisé à zéro
# en-tete de boucle :
#     #processus repetitif ici
#     if (événement qu'on cherche):
#         compte = compte + 1
# #à la fin de la boucle on sait combien de fois l'événement s'est produit.
# ```
#
# Appliquons cette recette à notre problème -- comme c'est un événement rare on va aussi augmenter le nombre de répétitions à 30 pour se donner une meilleure chance d'en voir:

# %%
compte = 0
for i in range(30):
    dé1 = random.randrange(1,7)
    dé2 = random.randrange(1,7)
    dé3 = random.randrange(1,7)
    print("les trois dés affichent:", dé1, dé2, dé3)
    if(dé1==dé2 and dé2==dé3):
        print("les trois valeurs sont égales !")
        compte = compte + 1
print("on a observé", compte, "fois trois dés égaux")
# Out:
# les trois dés affichent: 4 1 5
# les trois dés affichent: 6 5 5
# les trois dés affichent: 4 5 4
# les trois dés affichent: 4 1 6
# les trois dés affichent: 5 3 3
# les trois dés affichent: 5 2 3
# les trois dés affichent: 3 4 1
# les trois dés affichent: 3 6 2
# les trois dés affichent: 5 3 1
# les trois dés affichent: 2 3 4
# les trois dés affichent: 4 3 2
# les trois dés affichent: 2 6 5
# les trois dés affichent: 2 6 3
# les trois dés affichent: 1 5 2
# les trois dés affichent: 1 2 1
# les trois dés affichent: 1 3 6
# les trois dés affichent: 4 1 1
# les trois dés affichent: 1 4 6
# les trois dés affichent: 3 6 2
# les trois dés affichent: 3 3 4
# les trois dés affichent: 6 3 2
# les trois dés affichent: 2 4 2
# les trois dés affichent: 3 5 6
# les trois dés affichent: 1 6 1
# les trois dés affichent: 2 3 6
# les trois dés affichent: 5 6 5
# les trois dés affichent: 4 2 5
# les trois dés affichent: 4 4 3
# les trois dés affichent: 1 1 1
# les trois valeurs sont égales !
# les trois dés affichent: 2 1 2
# on a observé 1 fois trois dés égaux

# %% [markdown]
# On va maintenant augmenter le nombre de répétitions à 1 million, et réduire l'affichage:

# %%
compte = 0
for i in range(1000000):
    dé1 = random.randrange(1,7)
    dé2 = random.randrange(1,7)
    dé3 = random.randrange(1,7)
    #print("les trois dés affichent:", dé1, dé2, dé3)
    if(dé1==dé2 and dé2==dé3):
        #print("les trois valeurs sont égales !")
        compte = compte + 1
print("on a observé", compte, "fois trois dés égaux")
# Out:
# on a observé 27768 fois trois dés égaux

# %% [markdown]
# Comme on connait le nombre total d'expériences, on peut évaluer la probabilité (comme expliqué ci-dessus), et l'exprimer sous forme de pourcentage:

# %%
frequence = compte/1000000
# Out:
# La probabilité d'observer trois dés égaux est d'environ 2.7768 %.

# %% [markdown]
# Profitons pour introduire ici l'affichage _formaté_: on peut spécifier à l'aide de codes de formatage le nombre de chiffres affichés pour un nombre décimal. L'affichage formaté peut se faire de plusieurs façons différentes (voir documentation Python), en voici une:

# %%
pourcent = frequence*100
print(f"La probabilité d'observer trois dés égaux est d'environ {pourcent :.1f}%.")
# Out:
# La probabilité d'observer trois dés égaux est d'environ  2.8%.

# %% [markdown]
# Pour un affichage "formaté", on place la lettre ```f``` avant les quotes qui marquent le début de la chaîne de caractères à afficher, et on insère les variables dans le texte entre accolades. Pour des variables numériques décimales, on peut spécifier le nombre de chiffres à afficher à l'aide de codes de formatage. Pour plus de détails, voir la [documentation Python](https://docs.python.org/3/tutorial/inputoutput.html#tut-f-strings).

# %% [markdown]
# ## Exercice: jouer à la roulette
#
# Alice va au casino en espérant gagner de l’argent... Elle est optimiste! Elle est cependant réaliste, et aimerait savoir quelles sont ses chances d’atteindre son objectif, qui est de gagner \\$200 (de repartir avec \\$200 de plus que ce qu’elle apporte), et quelles sont ses chances d’être ruinée. On va simuler son activité́ au casino, et évaluer ces deux probabilités.
#
# Supposons qu’Alice veuille jouer à la roulette. On va simuler ici une version simplifiée du jeu. La roulette est un jeu où une bille est lancée sur une roue avec des numéros sur son pourtour, et quand la roue s’arrête, la bille se trouvera sur un numéro. Les numéros sont aussi placés sur des couleurs (rouge ou noir, sauf le zéro qui est sur une case verte). En pa-riant sur une couleur (rouge ou noir), Alice peut gagner une fois sa mise (elle récupère sa mise plus une fois cette quantité), et en pariant sur un numéro elle peut gagner 35 fois sa mise.
#
# Le but de l'exercice est donc de simuler le processus suivant: Alice débute avec une somme d'argent initiale de \\$1000, et joue à répétition à la roulette, en misant \\$5 sur le rouge, et \\$5 sur le numéro 23. Elle joue jusqu'à avoir atteint son objectif (arriver à \\$1200), ou bien jusqu'à être ruinée.
#
# On va ensuite simuler ce processus à répétition (1000 fois) et compter le nombre de fois où Alice termine ruinée et le nombre de fois où elle gagne \\$200, puis calculer la probabilité de gagner (selon cette définition).
#
# __2.1__ En utilisant la bibliothèque ```random```, simuler le fait de jouer une fois à la roulette: tirer un nombre entre 0 et 36, puis afficher le numéro et la couleur qui sont sortis. On supposera que le zéro est vert, les nombres impairs sont noirs, et les nombres pairs sont rouges (sauf le zéro).

# %%
numero = random.randrange(0,37)
if(numero==0):
    couleur= "vert"
elif(numero%2==0): 
    couleur = "rouge"
else:
    couleur = "noir"

print("le numéro", numero, "est sorti, couleur:", couleur)
# Out:
# le numéro 25 est sorti, couleur: noir

# %% [markdown]
# __2.2__ Alice mise toujours sur le rouge et le 23. Ajouter une instruction conditionnelle pour afficher "Gagné" quand Alice gagne.

# %%
if(couleur=="rouge" or numero==23):
    print("gagné")

# %% [markdown]
# __2.3__ Implémenter les paris: ajouter une variable ```budget```, et lui donner la valeur 1000. Au moment de jouer à la roulette, décompter \\$10 de son budget pour les mises (\\$5 pour le rouge, \\$5 pour le 23), et une fois que le résultat est connu, ajouter les gains à son budget quand elle gagne (35 fois la mise pour le 23, 2 fois la mise pour le rouge).
#
# __corrigé:__ on reprend le code depuis 2.1

# %%
budget = 1000
budget = budget - 10 # mises: $5 sur le rouge, $5 sur le 23
numero = random.randrange(0,37)
if(numero==0):
    couleur= "vert"
elif(numero%2==0): 
    couleur = "rouge"
else:
    couleur = "noir"

print("le numéro", numero, "est sorti, couleur:", couleur)

if(couleur=="rouge"):
    print("gagné")
    budget = budget + 2 * 5 # gain = 2x la mise
elif (numero==23):
    print("gagné")
    budget = budget + 35 * 5 # gain = 35x la mise
# Out:
# le numéro 6 est sorti, couleur: rouge
# gagné

# %% [markdown]
# __2.4__ Placer le code précédent dans une boucle, qui simule le fait qu'Alice joue jusqu’à ce qu’elle soit ruinée (son budget n’est plus suffisant pour miser) ou bien jusqu’à ce qu’elle atteigne son objectif (\\$1200). Attention: l'initialisation du budget (à \\$1000) doit se faire une seule fois, avant la boucle. Tester.

# %%
budget = 1000 # on débute initialement avec $1000... mais on ne revient pas à 1000 à chaque partie => initialisation hors de la boucle
while(budget >=10 and budget<1200):
    budget = budget - 10 # mises: $5 sur le rouge, $5 sur le 23
    numero = random.randrange(0,37)
    if(numero==0):
        couleur= "vert"
    elif(numero%2==0): 
        couleur = "rouge"
    else:
        couleur = "noir"

    print("le numéro", numero, "est sorti, couleur:", couleur)

    if(couleur=="rouge"):
        print("gagné")
        budget = budget + 2 * 5 # gain = 2x la mise
    elif (numero==23):
        print("gagné")
        budget = budget + 35 * 5 # gain = 35x la mise
# après le jeu...
if(budget >=1200):
    print ("Alice est riche!")
else:
    print ("Alice est ruinée!")
# Out:
# le numéro 15 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 29 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# Alice est riche!

# %% [markdown]
# __2.5__ Dans la simulation qu’on vient d’écrire, Alice va au casino et peut repartir avec \\$200 de plus en poche (succès!) ou ruinée (échec!). On va maintenant considérer ceci comme une seule expérience, et évaluer la probabilité de succès (qui est un des deux résultats possibles).
#
# Pour ceci, on va s’y prendre comme pour les lancers de dés : on va répéter l’expérience un grand nombre de fois, et compter les succès. Placer une boucle for de manière à répéter l’expérience 10 fois. Tester.

# %%
for i in range(10):# répéter 10 fois le contenu de la boucle...
    budget = 1000 # on débute initialement avec $1000... mais on ne revient pas à 1000 à chaque partie => initialisation hors de la boucle
    while(budget >=10 and budget<1200):
        budget = budget - 10 # mises: $5 sur le rouge, $5 sur le 23
        numero = random.randrange(0,37)
        if(numero==0):
            couleur= "vert"
        elif(numero%2==0): 
            couleur = "rouge"
        else:
            couleur = "noir"

        print("le numéro", numero, "est sorti, couleur:", couleur)
        
        if(couleur=="rouge"):
            print("gagné")
            budget = budget + 2 * 5 # gain = 2x la mise
        elif (numero==23):
            print("gagné")
            budget = budget + 35 * 5 # gain = 35x la mise
    # après le jeu...: hors boucle while mais dans boucle for
    if(budget >=1200):
        print ("Alice est riche!")
    else:
        print ("Alice est ruinée!")
# Out:
# le numéro 3 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 15 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 29 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 27 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 7 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 33 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 0 est sorti, couleur: vert
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 25 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 13 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 19 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 5 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 11 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# Alice est ruinée!
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# Alice est riche!
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 25 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 35 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 25 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 9 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 27 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# ...
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 25 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 17 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 29 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 25 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 33 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 5 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 9 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 31 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 5 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 29 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 1 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 7 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 2 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 15 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 25 est sorti, couleur: noir
# le numéro 16 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 19 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 11 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 14 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 5 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# Alice est ruinée!
# le numéro 5 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 19 est sorti, couleur: noir
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 0 est sorti, couleur: vert
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 21 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 3 est sorti, couleur: noir
# le numéro 35 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 11 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 31 est sorti, couleur: noir
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# Alice est riche!
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 13 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 9 est sorti, couleur: noir
# le numéro 20 est sorti, couleur: rouge
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 31 est sorti, couleur: noir
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 27 est sorti, couleur: noir
# le numéro 3 est sorti, couleur: noir
# le numéro 22 est sorti, couleur: rouge
# gagné
# le numéro 6 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 15 est sorti, couleur: noir
# le numéro 1 est sorti, couleur: noir
# le numéro 28 est sorti, couleur: rouge
# gagné
# le numéro 18 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 24 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 4 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 25 est sorti, couleur: noir
# le numéro 8 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 12 est sorti, couleur: rouge
# gagné
# le numéro 26 est sorti, couleur: rouge
# gagné
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# Alice est riche!
# le numéro 35 est sorti, couleur: noir
# le numéro 27 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 21 est sorti, couleur: noir
# le numéro 33 est sorti, couleur: noir
# le numéro 0 est sorti, couleur: vert
# le numéro 33 est sorti, couleur: noir
# le numéro 10 est sorti, couleur: rouge
# gagné
# le numéro 7 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 13 est sorti, couleur: noir
# le numéro 17 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 34 est sorti, couleur: rouge
# gagné
# le numéro 35 est sorti, couleur: noir
# le numéro 30 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# le numéro 36 est sorti, couleur: rouge
# gagné
# le numéro 32 est sorti, couleur: rouge
# gagné
# le numéro 23 est sorti, couleur: noir
# gagné
# Alice est riche!

# %% [markdown]
# __2.6__ Ajouter une variable ```nombreSucces``` et du code pour compter les succès. Enlever l’affichage à l’écran et augmenter le nombre d’expériences à 1000. Calculer ensuite la probabilité de succès (nombre de succès sur le nombre d’expériences) et la probabilité de ruine (100% moins la probabilité de succès). Afficher ces probabilités à l’écran.

# %%
nombreSucces = 0
for i in range(1000):# répéter 10 fois le contenu de la boucle...
    budget = 1000 # on débute initialement avec $1000... mais on ne revient pas à 1000 à chaque partie => initialisation hors de la boucle
    while(budget >=10 and budget<1200):
        budget = budget - 10 # mises: $5 sur le rouge, $5 sur le 23
        numero = random.randrange(0,37)
        if(numero==0):
            couleur= "vert"
        elif(numero%2==0): 
            couleur = "rouge"
        else:
            couleur = "noir"

        #print("le numéro", numero, "est sorti, couleur:", couleur)
        
        if(couleur=="rouge"):
        #   print("gagné")
            budget = budget + 2 * 5 # gain = 2x la mise
        elif (numero==23):
        #  print("gagné")
            budget = budget + 35 * 5 # gain = 35x la mise
    # après le jeu...: hors boucle while mais dans boucle for
    if(budget >=1200):
#        print ("Alice est riche!")
        nombreSucces = nombreSucces +1
#    else:
#        print ("Alice est ruinée!")
print("nombre de succes:", nombreSucces)
print("probabilité approximative:", int(nombreSucces/10),'%') #divisé par mille, x100 pour un pourcentage
# Out:
# nombre de succes: 681
# probabilité approximative: 68 %

# %% [markdown]
# ## Exercice: jeu de _craps_
#
# Dans cet exercice le but est de simuler une version simplifiée (_très_ simplifiée !) du jeu de "craps", un autre jeu de casino qui se joue avec des dés.
#
# Dans ce jeu il y a deux phases.
# Avant de commencer, le joueur mise soit sur "passe" soit sur "ne passe pas".
# Durant la phase initiale, le joueur lance deux dés, de manière répétée, jusqu'à obtenir 4, 5, 6, 8, 9, ou 10 (avec la somme des deux dés). Quand ceci se produit, le nombre obtenu devient "le point" et le jeu passe à sa deuxième phase.
# Durant la première phase, si le joueur obtient 7 ou 11, il double sa mise (la banque double la mise mais cette nouvelle mise reste sur le tapis pour la deuxième phase), et s'il obtient 2, 3, ou 12, il la perd. Il doit alors replacer une nouvelle mise, ou abandonner le jeu.
# Une fois qu'il a obtenu 4, 5, 6, 8, 9, ou 10 (le "point"), on est en deuxième phase, et le joueur doit lancer les dés de anière répétée jusqu'à gagner ou perdre. Pour gagner, il doit relancer le "point" (le même total, mais pas forcément la même combinaison de dés) avant d'obtenir 7. S'il obtient 7 avant de relancer le point, il perd. S'il gagne, il triple sa mise.
#
# Exemple de déroulement du jeu:
#
# 1. Le joueur mise \\$10 sur "passe".
# 2. Il lance : 2 1 => total 3 = ne passe pas... la mise est perdue!
# 3. Le joueur remet une nouvelle mise de \\$10.
# 4. Le joueur lance: 3 4 => total 7 = passe! la mise est doublée, maintenant elle est de \\$20!
# 5. Le joueur lance: 2 3 => total 5, c'est le point et on passe à la phase 2.
# 6. Le joueur lance : 3 6 => total 9, ni le point ni 7, il recommence;
# 7. Le joueur lance : 2 2 => total 4, ni le point ni 7, il recommence;
# 8. Le joueur lance : 6 1 => total 7, donc c'est perdu!
#
# Simuler un jeu de craps: comme pour la roulette, Alice arrive avec \\$1200 et joue à répétition, jusqu'à gagner $200 ou bien être ruinée. On supposera qu'elle misera toujours \\$10 sur "passe", et n'abandonne jamais sauf si elle est ruinée. Quelles sont ses chances de gagner?

# %%
montant_mise = 10
numvictoires = 0
for i in range(1000):
    budget = 1000
    numrounds = 0        
    while(budget > 5 and budget <1200):
        #print("new round =========")
        numrounds += 1
        #phase 1
        mise = montant_mise
        budget = budget - montant_mise
        #print("mise: ", mise)
        fini =False # si on perd sa mise pendant la phase 1
        while(True):
            de1 = random.randrange(1,7)
            de2 = random.randrange(1,7)
            val = de1 + de2
            #print("lancer:", de1, de2)
            if(val==7 or val==11): #passe
                #print("passe! mise doublée!")
                mise = mise *2 #on gagne => double la mise
                #print("mise: ", mise)
            elif (val ==2 or val==3 or val ==12):
                #print("ne passe pas... mise perdue!")
                mise = montant_mise # tout perdu! on remet une mise
                #print("mise: ", mise)
                budget -= montant_mise    
                if (budget <0): #si on n'a plus d'argent il faut quitter le processus 
                    fini = True
                    break
            else:
                lepoint = val
                #print("-- point:", lepoint)
                break
        # if (fini) => on saute ceci et on va directement quitter a cause de la boucle while
        if (not fini): #il nous reste de l'argent
            de1 = random.randrange(1,7)
            de2 = random.randrange(1,7)
            val = de1 + de2
            #print("lancer:", de1, de2)
            while (val != 7 and val!=lepoint):
                de1 = random.randrange(1,7)
                de2 = random.randrange(1,7)
                val = de1 + de2
                #print("lancer:", de1, de2)
            if (val==lepoint): #gagné
                budget = budget + (2*mise)
                #print("gagné! ========", budget)
            #else:
                #print("perdu =========", budget)
    if(budget==1200):
        print("vous avez gagné bravo! rounds:", numrounds)
        numvictoires += 1
    else:
        print("vous etes ruiné! rounds:", numrounds)
proba = int(numvictoires / 10)
print ("probabilité approximative de gagner:", proba,"%")
# Out:
# vous etes ruiné! rounds: 575
# vous avez gagné bravo! rounds: 143
# vous etes ruiné! rounds: 608
# vous etes ruiné! rounds: 1152
# vous etes ruiné! rounds: 183
# vous etes ruiné! rounds: 262
# vous etes ruiné! rounds: 2292
# vous etes ruiné! rounds: 164
# vous etes ruiné! rounds: 1320
# vous etes ruiné! rounds: 1718
# vous etes ruiné! rounds: 394
# vous avez gagné bravo! rounds: 65
# vous avez gagné bravo! rounds: 370
# vous avez gagné bravo! rounds: 108
# vous etes ruiné! rounds: 310
# vous etes ruiné! rounds: 2268
# vous avez gagné bravo! rounds: 94
# vous avez gagné bravo! rounds: 108
# vous etes ruiné! rounds: 36
# vous etes ruiné! rounds: 1771
# vous etes ruiné! rounds: 581
# vous etes ruiné! rounds: 815
# vous etes ruiné! rounds: 19
# vous etes ruiné! rounds: 816
# vous etes ruiné! rounds: 484
# vous etes ruiné! rounds: 601
# vous etes ruiné! rounds: 569
# vous avez gagné bravo! rounds: 220
# vous avez gagné bravo! rounds: 952
# vous etes ruiné! rounds: 124
# vous avez gagné bravo! rounds: 184
# vous etes ruiné! rounds: 2184
# vous etes ruiné! rounds: 114
# vous etes ruiné! rounds: 138
# vous etes ruiné! rounds: 288
# vous avez gagné bravo! rounds: 48
# vous avez gagné bravo! rounds: 130
# vous etes ruiné! rounds: 410
# vous etes ruiné! rounds: 730
# vous etes ruiné! rounds: 841
# vous avez gagné bravo! rounds: 25
# vous etes ruiné! rounds: 2003
# vous etes ruiné! rounds: 645
# vous etes ruiné! rounds: 65
# vous avez gagné bravo! rounds: 334
# vous etes ruiné! rounds: 1238
# vous etes ruiné! rounds: 405
# vous etes ruiné! rounds: 722
# vous avez gagné bravo! rounds: 390
# vous etes ruiné! rounds: 147
# vous etes ruiné! rounds: 517
# vous etes ruiné! rounds: 10
# vous etes ruiné! rounds: 847
# vous etes ruiné! rounds: 28
# vous etes ruiné! rounds: 664
# vous etes ruiné! rounds: 94
# vous etes ruiné! rounds: 1270
# vous avez gagné bravo! rounds: 67
# vous etes ruiné! rounds: 911
# vous avez gagné bravo! rounds: 389
# vous etes ruiné! rounds: 195
# vous etes ruiné! rounds: 554
# vous etes ruiné! rounds: 905
# vous etes ruiné! rounds: 988
# vous etes ruiné! rounds: 107
# vous etes ruiné! rounds: 23
# vous etes ruiné! rounds: 57
# vous etes ruiné! rounds: 75
# vous etes ruiné! rounds: 1173
# vous etes ruiné! rounds: 74
# vous etes ruiné! rounds: 44
# vous etes ruiné! rounds: 524
# vous etes ruiné! rounds: 443
# vous etes ruiné! rounds: 69
# vous etes ruiné! rounds: 2084
# vous etes ruiné! rounds: 39
# vous etes ruiné! rounds: 906
# vous etes ruiné! rounds: 240
# vous etes ruiné! rounds: 357
# vous etes ruiné! rounds: 251
# vous etes ruiné! rounds: 9
# vous etes ruiné! rounds: 1128
# vous etes ruiné! rounds: 587
# vous etes ruiné! rounds: 656
# vous etes ruiné! rounds: 1912
# vous avez gagné bravo! rounds: 292
# vous etes ruiné! rounds: 1960
# vous etes ruiné! rounds: 335
# vous etes ruiné! rounds: 1097
# vous avez gagné bravo! rounds: 400
# vous etes ruiné! rounds: 651
# vous etes ruiné! rounds: 988
# vous avez gagné bravo! rounds: 169
# vous etes ruiné! rounds: 1094
# vous etes ruiné! rounds: 967
# vous etes ruiné! rounds: 34
# vous etes ruiné! rounds: 2272
# vous etes ruiné! rounds: 12
# vous etes ruiné! rounds: 225
# vous etes ruiné! rounds: 674
# vous etes ruiné! rounds: 447
# vous etes ruiné! rounds: 1867
# vous etes ruiné! rounds: 409
# vous avez gagné bravo! rounds: 145
# vous etes ruiné! rounds: 1741
# vous etes ruiné! rounds: 546
# vous avez gagné bravo! rounds: 120
# vous etes ruiné! rounds: 233
# vous etes ruiné! rounds: 738
# vous etes ruiné! rounds: 2058
# vous etes ruiné! rounds: 1346
# vous etes ruiné! rounds: 45
# vous etes ruiné! rounds: 1413
# vous etes ruiné! rounds: 8
# vous etes ruiné! rounds: 635
# vous etes ruiné! rounds: 144
# vous avez gagné bravo! rounds: 183
# vous etes ruiné! rounds: 73
# vous etes ruiné! rounds: 1215
# vous etes ruiné! rounds: 1160
# vous etes ruiné! rounds: 498
# vous avez gagné bravo! rounds: 121
# vous etes ruiné! rounds: 968
# vous etes ruiné! rounds: 2344
# vous etes ruiné! rounds: 849
# vous avez gagné bravo! rounds: 47
# vous etes ruiné! rounds: 963
# vous etes ruiné! rounds: 738
# vous etes ruiné! rounds: 470
# vous etes ruiné! rounds: 303
# vous etes ruiné! rounds: 1380
# vous etes ruiné! rounds: 1461
# vous etes ruiné! rounds: 174
# vous avez gagné bravo! rounds: 34
# vous etes ruiné! rounds: 64
# vous avez gagné bravo! rounds: 296
# vous etes ruiné! rounds: 459
# vous etes ruiné! rounds: 1420
# vous etes ruiné! rounds: 631
# vous etes ruiné! rounds: 33
# vous etes ruiné! rounds: 205
# vous etes ruiné! rounds: 75
# vous etes ruiné! rounds: 1769
# vous etes ruiné! rounds: 594
# vous avez gagné bravo! rounds: 163
# vous etes ruiné! rounds: 24
# vous etes ruiné! rounds: 2350
# vous etes ruiné! rounds: 658
# vous avez gagné bravo! rounds: 23
# vous etes ruiné! rounds: 19
# vous etes ruiné! rounds: 80
# vous etes ruiné! rounds: 70
# vous etes ruiné! rounds: 484
# vous avez gagné bravo! rounds: 268
# vous etes ruiné! rounds: 125
# vous avez gagné bravo! rounds: 1282
# vous avez gagné bravo! rounds: 578
# vous etes ruiné! rounds: 2934
# vous etes ruiné! rounds: 1721
# vous etes ruiné! rounds: 1138
# vous etes ruiné! rounds: 628
# vous etes ruiné! rounds: 11
# vous etes ruiné! rounds: 101
# vous etes ruiné! rounds: 2403
# vous etes ruiné! rounds: 1257
# vous etes ruiné! rounds: 2304
# vous avez gagné bravo! rounds: 9
# vous etes ruiné! rounds: 471
# vous avez gagné bravo! rounds: 132
# vous etes ruiné! rounds: 1199
# vous etes ruiné! rounds: 39
# vous etes ruiné! rounds: 2024
# vous etes ruiné! rounds: 95
# vous avez gagné bravo! rounds: 1274
# vous avez gagné bravo! rounds: 290
# vous etes ruiné! rounds: 458
# vous etes ruiné! rounds: 22
# vous etes ruiné! rounds: 134
# vous etes ruiné! rounds: 249
# vous etes ruiné! rounds: 702
# vous avez gagné bravo! rounds: 183
# vous etes ruiné! rounds: 109
# vous etes ruiné! rounds: 1831
# vous avez gagné bravo! rounds: 172
# vous etes ruiné! rounds: 158
# vous etes ruiné! rounds: 1442
# vous etes ruiné! rounds: 364
# vous avez gagné bravo! rounds: 269
# vous etes ruiné! rounds: 141
# vous etes ruiné! rounds: 1045
# vous etes ruiné! rounds: 907
# vous etes ruiné! rounds: 1344
# vous etes ruiné! rounds: 668
# vous avez gagné bravo! rounds: 52
# vous etes ruiné! rounds: 881
# vous etes ruiné! rounds: 231
# vous etes ruiné! rounds: 1949
# vous etes ruiné! rounds: 679
# vous etes ruiné! rounds: 756
# vous etes ruiné! rounds: 57
# vous avez gagné bravo! rounds: 152
# vous etes ruiné! rounds: 155
# vous avez gagné bravo! rounds: 51
# vous etes ruiné! rounds: 530
# vous etes ruiné! rounds: 649
# vous etes ruiné! rounds: 304
# vous avez gagné bravo! rounds: 360
# vous etes ruiné! rounds: 994
# vous avez gagné bravo! rounds: 52
# vous etes ruiné! rounds: 649
# vous etes ruiné! rounds: 447
# vous etes ruiné! rounds: 741
# vous avez gagné bravo! rounds: 441
# vous etes ruiné! rounds: 1421
# vous avez gagné bravo! rounds: 42
# vous etes ruiné! rounds: 343
# vous etes ruiné! rounds: 118
# vous etes ruiné! rounds: 893
# vous etes ruiné! rounds: 1921
# vous etes ruiné! rounds: 277
# vous etes ruiné! rounds: 80
# vous etes ruiné! rounds: 722
# vous etes ruiné! rounds: 1374
# vous avez gagné bravo! rounds: 511
# vous etes ruiné! rounds: 703
# vous etes ruiné! rounds: 48
# vous etes ruiné! rounds: 689
# vous etes ruiné! rounds: 695
# vous avez gagné bravo! rounds: 219
# vous etes ruiné! rounds: 1202
# vous avez gagné bravo! rounds: 6
# vous etes ruiné! rounds: 11
# vous etes ruiné! rounds: 1245
# vous etes ruiné! rounds: 2926
# vous etes ruiné! rounds: 177
# vous etes ruiné! rounds: 239
# vous etes ruiné! rounds: 56
# vous etes ruiné! rounds: 44
# vous avez gagné bravo! rounds: 114
# vous etes ruiné! rounds: 2392
# vous etes ruiné! rounds: 8
# vous avez gagné bravo! rounds: 186
# vous etes ruiné! rounds: 890
# vous etes ruiné! rounds: 531
# vous avez gagné bravo! rounds: 132
# vous etes ruiné! rounds: 33
# vous etes ruiné! rounds: 80
# vous etes ruiné! rounds: 608
# vous etes ruiné! rounds: 1039
# vous etes ruiné! rounds: 119
# vous etes ruiné! rounds: 222
# vous etes ruiné! rounds: 33
# vous etes ruiné! rounds: 611
# vous etes ruiné! rounds: 489
# vous etes ruiné! rounds: 473
# vous etes ruiné! rounds: 29
# vous etes ruiné! rounds: 966
# vous avez gagné bravo! rounds: 1960
# vous etes ruiné! rounds: 198
# vous etes ruiné! rounds: 1460
# vous etes ruiné! rounds: 1409
# vous etes ruiné! rounds: 98
# vous etes ruiné! rounds: 833
# vous avez gagné bravo! rounds: 15
# vous etes ruiné! rounds: 199
# vous etes ruiné! rounds: 451
# vous etes ruiné! rounds: 1169
# vous etes ruiné! rounds: 2246
# vous etes ruiné! rounds: 1630
# vous etes ruiné! rounds: 337
# vous avez gagné bravo! rounds: 65
# vous etes ruiné! rounds: 1382
# vous avez gagné bravo! rounds: 308
# vous etes ruiné! rounds: 703
# vous etes ruiné! rounds: 16
# vous etes ruiné! rounds: 1
# vous etes ruiné! rounds: 66
# vous etes ruiné! rounds: 506
# vous etes ruiné! rounds: 789
# vous etes ruiné! rounds: 730
# vous etes ruiné! rounds: 250
# vous avez gagné bravo! rounds: 30
# vous etes ruiné! rounds: 1090
# vous etes ruiné! rounds: 552
# vous etes ruiné! rounds: 785
# vous avez gagné bravo! rounds: 21
# vous etes ruiné! rounds: 800
# vous etes ruiné! rounds: 580
# vous etes ruiné! rounds: 845
# vous etes ruiné! rounds: 2258
# vous etes ruiné! rounds: 582
# vous etes ruiné! rounds: 1273
# vous etes ruiné! rounds: 37
# vous etes ruiné! rounds: 1317
# vous etes ruiné! rounds: 610
# vous etes ruiné! rounds: 672
# vous avez gagné bravo! rounds: 1148
# vous etes ruiné! rounds: 695
# vous etes ruiné! rounds: 1033
# vous etes ruiné! rounds: 843
# vous etes ruiné! rounds: 332
# vous etes ruiné! rounds: 1445
# vous etes ruiné! rounds: 46
# vous etes ruiné! rounds: 1573
# vous etes ruiné! rounds: 75
# vous avez gagné bravo! rounds: 585
# vous etes ruiné! rounds: 520
# vous etes ruiné! rounds: 534
# vous avez gagné bravo! rounds: 245
# vous etes ruiné! rounds: 1015
# vous etes ruiné! rounds: 680
# vous etes ruiné! rounds: 368
# vous etes ruiné! rounds: 304
# vous etes ruiné! rounds: 979
# vous etes ruiné! rounds: 36
# vous etes ruiné! rounds: 346
# vous etes ruiné! rounds: 1307
# vous etes ruiné! rounds: 653
# vous etes ruiné! rounds: 365
# vous etes ruiné! rounds: 751
# vous etes ruiné! rounds: 1002
# vous etes ruiné! rounds: 404
# vous etes ruiné! rounds: 51
# vous etes ruiné! rounds: 790
# vous etes ruiné! rounds: 23
# vous etes ruiné! rounds: 12
# vous etes ruiné! rounds: 1160
# vous etes ruiné! rounds: 169
# vous etes ruiné! rounds: 1929
# vous etes ruiné! rounds: 274
# vous etes ruiné! rounds: 11
# vous etes ruiné! rounds: 513
# vous etes ruiné! rounds: 156
# vous etes ruiné! rounds: 288
# vous etes ruiné! rounds: 2019
# vous etes ruiné! rounds: 87
# vous avez gagné bravo! rounds: 215
# vous etes ruiné! rounds: 479
# vous etes ruiné! rounds: 917
# vous avez gagné bravo! rounds: 79
# vous etes ruiné! rounds: 128
# vous etes ruiné! rounds: 1101
# vous etes ruiné! rounds: 1113
# vous avez gagné bravo! rounds: 75
# vous avez gagné bravo! rounds: 82
# vous etes ruiné! rounds: 3992
# vous etes ruiné! rounds: 903
# vous etes ruiné! rounds: 699
# vous etes ruiné! rounds: 156
# vous etes ruiné! rounds: 3
# vous etes ruiné! rounds: 463
# vous etes ruiné! rounds: 201
# vous etes ruiné! rounds: 948
# vous etes ruiné! rounds: 1971
# vous etes ruiné! rounds: 609
# vous etes ruiné! rounds: 285
# vous etes ruiné! rounds: 906
# vous etes ruiné! rounds: 332
# vous etes ruiné! rounds: 1023
# vous etes ruiné! rounds: 105
# vous etes ruiné! rounds: 581
# vous etes ruiné! rounds: 306
# vous etes ruiné! rounds: 584
# vous etes ruiné! rounds: 75
# vous etes ruiné! rounds: 613
# vous etes ruiné! rounds: 933
# vous avez gagné bravo! rounds: 155
# vous avez gagné bravo! rounds: 518
# vous avez gagné bravo! rounds: 36
# vous etes ruiné! rounds: 185
# vous etes ruiné! rounds: 306
# vous etes ruiné! rounds: 371
# vous avez gagné bravo! rounds: 320
# vous etes ruiné! rounds: 163
# vous etes ruiné! rounds: 1310
# vous etes ruiné! rounds: 457
# vous etes ruiné! rounds: 655
# vous etes ruiné! rounds: 300
# vous etes ruiné! rounds: 688
# vous etes ruiné! rounds: 424
# vous etes ruiné! rounds: 1074
# vous avez gagné bravo! rounds: 821
# vous avez gagné bravo! rounds: 27
# vous etes ruiné! rounds: 928
# vous avez gagné bravo! rounds: 86
# vous etes ruiné! rounds: 456
# vous etes ruiné! rounds: 624
# vous etes ruiné! rounds: 77
# vous etes ruiné! rounds: 1164
# vous etes ruiné! rounds: 438
# vous etes ruiné! rounds: 1184
# vous etes ruiné! rounds: 807
# vous etes ruiné! rounds: 815
# vous etes ruiné! rounds: 896
# vous etes ruiné! rounds: 210
# vous etes ruiné! rounds: 656
# vous etes ruiné! rounds: 94
# vous etes ruiné! rounds: 302
# vous etes ruiné! rounds: 65
# vous etes ruiné! rounds: 247
# vous etes ruiné! rounds: 642
# vous etes ruiné! rounds: 187
# vous etes ruiné! rounds: 1405
# vous etes ruiné! rounds: 522
# vous etes ruiné! rounds: 605
# vous etes ruiné! rounds: 1826
# vous etes ruiné! rounds: 681
# vous avez gagné bravo! rounds: 168
# vous etes ruiné! rounds: 492
# vous etes ruiné! rounds: 202
# vous etes ruiné! rounds: 36
# vous etes ruiné! rounds: 883
# vous avez gagné bravo! rounds: 307
# vous etes ruiné! rounds: 729
# vous etes ruiné! rounds: 1281
# vous etes ruiné! rounds: 143
# vous etes ruiné! rounds: 585
# vous avez gagné bravo! rounds: 680
# vous etes ruiné! rounds: 431
# vous etes ruiné! rounds: 84
# vous etes ruiné! rounds: 1062
# vous etes ruiné! rounds: 868
# vous etes ruiné! rounds: 99
# vous avez gagné bravo! rounds: 65
# vous etes ruiné! rounds: 174
# vous etes ruiné! rounds: 423
# vous etes ruiné! rounds: 173
# vous etes ruiné! rounds: 1967
# vous etes ruiné! rounds: 1350
# vous etes ruiné! rounds: 1490
# vous avez gagné bravo! rounds: 217
# vous etes ruiné! rounds: 64
# vous avez gagné bravo! rounds: 41
# vous etes ruiné! rounds: 27
# vous etes ruiné! rounds: 1921
# vous etes ruiné! rounds: 2061
# vous avez gagné bravo! rounds: 401
# vous etes ruiné! rounds: 356
# vous etes ruiné! rounds: 174
# vous avez gagné bravo! rounds: 36
# vous etes ruiné! rounds: 682
# vous etes ruiné! rounds: 8
# vous etes ruiné! rounds: 1047
# vous etes ruiné! rounds: 73
# vous etes ruiné! rounds: 96
# vous avez gagné bravo! rounds: 83
# vous etes ruiné! rounds: 554
# vous etes ruiné! rounds: 627
# vous etes ruiné! rounds: 1147
# vous etes ruiné! rounds: 312
# vous avez gagné bravo! rounds: 921
# vous etes ruiné! rounds: 1119
# vous etes ruiné! rounds: 772
# vous etes ruiné! rounds: 1178
# vous etes ruiné! rounds: 1849
# vous etes ruiné! rounds: 161
# vous etes ruiné! rounds: 910
# vous etes ruiné! rounds: 683
# vous etes ruiné! rounds: 51
# vous etes ruiné! rounds: 587
# vous etes ruiné! rounds: 814
# vous avez gagné bravo! rounds: 226
# vous avez gagné bravo! rounds: 161
# vous avez gagné bravo! rounds: 221
# vous etes ruiné! rounds: 126
# vous etes ruiné! rounds: 489
# vous etes ruiné! rounds: 515
# vous etes ruiné! rounds: 136
# vous etes ruiné! rounds: 111
# vous etes ruiné! rounds: 11
# vous etes ruiné! rounds: 1023
# vous etes ruiné! rounds: 1726
# vous etes ruiné! rounds: 1859
# vous etes ruiné! rounds: 127
# vous etes ruiné! rounds: 1899
# vous etes ruiné! rounds: 301
# vous etes ruiné! rounds: 1478
# vous etes ruiné! rounds: 422
# vous etes ruiné! rounds: 781
# vous etes ruiné! rounds: 865
# vous etes ruiné! rounds: 1039
# vous avez gagné bravo! rounds: 192
# vous avez gagné bravo! rounds: 1406
# vous avez gagné bravo! rounds: 31
# vous etes ruiné! rounds: 1152
# vous etes ruiné! rounds: 201
# vous etes ruiné! rounds: 1754
# vous etes ruiné! rounds: 34
# vous etes ruiné! rounds: 331
# vous etes ruiné! rounds: 136
# vous etes ruiné! rounds: 133
# vous etes ruiné! rounds: 609
# vous etes ruiné! rounds: 884
# vous avez gagné bravo! rounds: 103
# vous avez gagné bravo! rounds: 49
# vous avez gagné bravo! rounds: 458
# vous etes ruiné! rounds: 84
# vous avez gagné bravo! rounds: 20
# vous etes ruiné! rounds: 1739
# vous etes ruiné! rounds: 74
# vous avez gagné bravo! rounds: 62
# vous etes ruiné! rounds: 814
# vous etes ruiné! rounds: 957
# vous etes ruiné! rounds: 24
# vous avez gagné bravo! rounds: 9
# vous avez gagné bravo! rounds: 1047
# vous avez gagné bravo! rounds: 13
# vous avez gagné bravo! rounds: 411
# vous avez gagné bravo! rounds: 209
# vous avez gagné bravo! rounds: 1522
# vous etes ruiné! rounds: 611
# vous etes ruiné! rounds: 80
# vous etes ruiné! rounds: 10
# vous etes ruiné! rounds: 1077
# vous etes ruiné! rounds: 46
# vous etes ruiné! rounds: 897
# vous etes ruiné! rounds: 85
# vous avez gagné bravo! rounds: 14
# vous etes ruiné! rounds: 49
# vous etes ruiné! rounds: 1064
# vous etes ruiné! rounds: 61
# vous etes ruiné! rounds: 388
# vous etes ruiné! rounds: 55
# vous etes ruiné! rounds: 160
# vous etes ruiné! rounds: 740
# vous etes ruiné! rounds: 219
# vous etes ruiné! rounds: 926
# vous etes ruiné! rounds: 216
# vous etes ruiné! rounds: 223
# vous etes ruiné! rounds: 184
# vous etes ruiné! rounds: 1535
# vous etes ruiné! rounds: 1424
# vous etes ruiné! rounds: 713
# vous etes ruiné! rounds: 445
# vous etes ruiné! rounds: 1160
# vous avez gagné bravo! rounds: 215
# vous etes ruiné! rounds: 1315
# vous etes ruiné! rounds: 649
# vous etes ruiné! rounds: 51
# vous avez gagné bravo! rounds: 178
# vous etes ruiné! rounds: 920
# vous etes ruiné! rounds: 16
# vous etes ruiné! rounds: 461
# vous etes ruiné! rounds: 441
# vous etes ruiné! rounds: 764
# vous avez gagné bravo! rounds: 1154
# vous etes ruiné! rounds: 94
# vous etes ruiné! rounds: 925
# vous etes ruiné! rounds: 914
# vous etes ruiné! rounds: 1327
# vous etes ruiné! rounds: 843
# vous etes ruiné! rounds: 596
# vous etes ruiné! rounds: 76
# vous etes ruiné! rounds: 733
# vous etes ruiné! rounds: 721
# vous etes ruiné! rounds: 7
# vous etes ruiné! rounds: 801
# vous etes ruiné! rounds: 458
# vous etes ruiné! rounds: 20
# vous etes ruiné! rounds: 189
# vous etes ruiné! rounds: 577
# vous etes ruiné! rounds: 12
# vous etes ruiné! rounds: 369
# vous etes ruiné! rounds: 2833
# vous etes ruiné! rounds: 403
# vous etes ruiné! rounds: 533
# vous etes ruiné! rounds: 2058
# vous avez gagné bravo! rounds: 613
# vous etes ruiné! rounds: 629
# vous avez gagné bravo! rounds: 145
# vous avez gagné bravo! rounds: 14
# vous etes ruiné! rounds: 1575
# vous etes ruiné! rounds: 1246
# vous etes ruiné! rounds: 15
# vous etes ruiné! rounds: 519
# vous avez gagné bravo! rounds: 58
# vous etes ruiné! rounds: 994
# vous avez gagné bravo! rounds: 734
# vous etes ruiné! rounds: 16
# vous etes ruiné! rounds: 344
# vous etes ruiné! rounds: 589
# vous avez gagné bravo! rounds: 179
# vous etes ruiné! rounds: 308
# vous etes ruiné! rounds: 1980
# vous avez gagné bravo! rounds: 853
# vous avez gagné bravo! rounds: 23
# vous etes ruiné! rounds: 406
# vous etes ruiné! rounds: 302
# vous etes ruiné! rounds: 1436
# vous etes ruiné! rounds: 75
# vous etes ruiné! rounds: 109
# vous avez gagné bravo! rounds: 322
# vous etes ruiné! rounds: 1133
# vous etes ruiné! rounds: 74
# vous etes ruiné! rounds: 555
# vous etes ruiné! rounds: 1656
# vous avez gagné bravo! rounds: 102
# vous etes ruiné! rounds: 21
# vous etes ruiné! rounds: 26
# vous etes ruiné! rounds: 1540
# vous etes ruiné! rounds: 1454
# vous etes ruiné! rounds: 716
# vous etes ruiné! rounds: 850
# vous etes ruiné! rounds: 959
# vous etes ruiné! rounds: 171
# vous etes ruiné! rounds: 904
# vous etes ruiné! rounds: 2117
# vous etes ruiné! rounds: 82
# vous avez gagné bravo! rounds: 219
# vous avez gagné bravo! rounds: 60
# vous etes ruiné! rounds: 666
# vous etes ruiné! rounds: 365
# vous etes ruiné! rounds: 719
# vous etes ruiné! rounds: 284
# vous etes ruiné! rounds: 48
# vous etes ruiné! rounds: 729
# vous avez gagné bravo! rounds: 40
# vous etes ruiné! rounds: 877
# vous etes ruiné! rounds: 934
# vous etes ruiné! rounds: 1270
# vous etes ruiné! rounds: 1181
# vous avez gagné bravo! rounds: 146
# vous etes ruiné! rounds: 275
# vous etes ruiné! rounds: 2133
# vous avez gagné bravo! rounds: 44
# vous etes ruiné! rounds: 1123
# vous etes ruiné! rounds: 307
# vous etes ruiné! rounds: 269
# vous etes ruiné! rounds: 67
# vous etes ruiné! rounds: 1514
# vous etes ruiné! rounds: 860
# vous etes ruiné! rounds: 194
# vous etes ruiné! rounds: 2070
# vous etes ruiné! rounds: 1134
# vous etes ruiné! rounds: 104
# vous etes ruiné! rounds: 295
# vous etes ruiné! rounds: 1420
# vous avez gagné bravo! rounds: 76
# vous etes ruiné! rounds: 1010
# vous etes ruiné! rounds: 655
# vous etes ruiné! rounds: 1064
# vous etes ruiné! rounds: 171
# vous etes ruiné! rounds: 87
# vous etes ruiné! rounds: 374
# vous etes ruiné! rounds: 16
# vous etes ruiné! rounds: 1563
# vous etes ruiné! rounds: 25
# vous etes ruiné! rounds: 1382
# vous etes ruiné! rounds: 2234
# vous etes ruiné! rounds: 109
# vous avez gagné bravo! rounds: 49
# vous etes ruiné! rounds: 852
# vous avez gagné bravo! rounds: 616
# vous etes ruiné! rounds: 219
# vous avez gagné bravo! rounds: 193
# vous etes ruiné! rounds: 394
# vous avez gagné bravo! rounds: 113
# vous etes ruiné! rounds: 198
# vous etes ruiné! rounds: 1666
# vous avez gagné bravo! rounds: 390
# vous avez gagné bravo! rounds: 1852
# vous etes ruiné! rounds: 36
# vous etes ruiné! rounds: 599
# vous etes ruiné! rounds: 645
# vous etes ruiné! rounds: 1216
# vous avez gagné bravo! rounds: 59
# vous avez gagné bravo! rounds: 21
# vous etes ruiné! rounds: 118
# vous avez gagné bravo! rounds: 52
# vous etes ruiné! rounds: 3288
# vous etes ruiné! rounds: 319
# vous avez gagné bravo! rounds: 539
# vous avez gagné bravo! rounds: 69
# vous etes ruiné! rounds: 298
# vous etes ruiné! rounds: 1153
# vous etes ruiné! rounds: 737
# vous etes ruiné! rounds: 240
# vous etes ruiné! rounds: 591
# vous etes ruiné! rounds: 539
# vous etes ruiné! rounds: 1093
# vous etes ruiné! rounds: 584
# vous etes ruiné! rounds: 38
# vous etes ruiné! rounds: 1095
# vous etes ruiné! rounds: 725
# vous avez gagné bravo! rounds: 72
# vous etes ruiné! rounds: 416
# vous etes ruiné! rounds: 989
# vous avez gagné bravo! rounds: 122
# vous etes ruiné! rounds: 805
# vous etes ruiné! rounds: 84
# vous etes ruiné! rounds: 18
# vous etes ruiné! rounds: 435
# vous etes ruiné! rounds: 28
# vous etes ruiné! rounds: 27
# vous etes ruiné! rounds: 48
# vous etes ruiné! rounds: 1024
# vous etes ruiné! rounds: 656
# vous etes ruiné! rounds: 1713
# vous etes ruiné! rounds: 33
# vous etes ruiné! rounds: 353
# vous etes ruiné! rounds: 197
# vous etes ruiné! rounds: 2091
# vous etes ruiné! rounds: 1761
# vous etes ruiné! rounds: 106
# vous avez gagné bravo! rounds: 716
# vous etes ruiné! rounds: 705
# vous etes ruiné! rounds: 42
# vous etes ruiné! rounds: 654
# vous etes ruiné! rounds: 990
# vous avez gagné bravo! rounds: 222
# vous etes ruiné! rounds: 813
# vous etes ruiné! rounds: 1034
# vous etes ruiné! rounds: 1353
# vous avez gagné bravo! rounds: 289
# vous etes ruiné! rounds: 1799
# vous etes ruiné! rounds: 2756
# vous etes ruiné! rounds: 159
# vous avez gagné bravo! rounds: 8
# vous etes ruiné! rounds: 508
# vous etes ruiné! rounds: 1280
# vous etes ruiné! rounds: 415
# vous etes ruiné! rounds: 552
# vous etes ruiné! rounds: 756
# vous etes ruiné! rounds: 42
# vous etes ruiné! rounds: 1545
# vous etes ruiné! rounds: 801
# vous etes ruiné! rounds: 782
# vous etes ruiné! rounds: 20
# vous etes ruiné! rounds: 474
# vous etes ruiné! rounds: 1536
# vous etes ruiné! rounds: 173
# vous etes ruiné! rounds: 598
# vous etes ruiné! rounds: 246
# vous etes ruiné! rounds: 77
# vous avez gagné bravo! rounds: 52
# vous avez gagné bravo! rounds: 76
# vous etes ruiné! rounds: 148
# vous etes ruiné! rounds: 871
# vous etes ruiné! rounds: 42
# vous avez gagné bravo! rounds: 196
# vous etes ruiné! rounds: 397
# vous etes ruiné! rounds: 4670
# vous etes ruiné! rounds: 1025
# vous etes ruiné! rounds: 1211
# vous etes ruiné! rounds: 1119
# vous etes ruiné! rounds: 1272
# vous etes ruiné! rounds: 1170
# vous etes ruiné! rounds: 235
# vous etes ruiné! rounds: 336
# vous etes ruiné! rounds: 872
# vous etes ruiné! rounds: 966
# vous etes ruiné! rounds: 550
# vous avez gagné bravo! rounds: 226
# vous etes ruiné! rounds: 644
# vous etes ruiné! rounds: 808
# vous etes ruiné! rounds: 1201
# vous etes ruiné! rounds: 109
# vous avez gagné bravo! rounds: 175
# vous avez gagné bravo! rounds: 1618
# vous avez gagné bravo! rounds: 422
# vous etes ruiné! rounds: 72
# vous etes ruiné! rounds: 692
# vous avez gagné bravo! rounds: 110
# vous avez gagné bravo! rounds: 101
# vous etes ruiné! rounds: 1248
# vous etes ruiné! rounds: 1051
# vous etes ruiné! rounds: 580
# vous etes ruiné! rounds: 461
# vous etes ruiné! rounds: 1199
# vous etes ruiné! rounds: 274
# vous etes ruiné! rounds: 591
# vous etes ruiné! rounds: 371
# vous avez gagné bravo! rounds: 42
# vous etes ruiné! rounds: 770
# vous etes ruiné! rounds: 390
# vous avez gagné bravo! rounds: 77
# vous etes ruiné! rounds: 74
# vous etes ruiné! rounds: 598
# vous etes ruiné! rounds: 1329
# vous etes ruiné! rounds: 2044
# vous etes ruiné! rounds: 538
# vous etes ruiné! rounds: 743
# vous avez gagné bravo! rounds: 292
# vous etes ruiné! rounds: 1377
# vous avez gagné bravo! rounds: 287
# vous etes ruiné! rounds: 21
# vous etes ruiné! rounds: 42
# vous etes ruiné! rounds: 2002
# vous avez gagné bravo! rounds: 41
# vous etes ruiné! rounds: 701
# vous etes ruiné! rounds: 82
# vous etes ruiné! rounds: 1106
# vous etes ruiné! rounds: 765
# vous avez gagné bravo! rounds: 686
# vous etes ruiné! rounds: 1896
# vous etes ruiné! rounds: 187
# vous etes ruiné! rounds: 307
# vous etes ruiné! rounds: 98
# vous etes ruiné! rounds: 1679
# vous etes ruiné! rounds: 1175
# vous etes ruiné! rounds: 1225
# vous avez gagné bravo! rounds: 72
# vous etes ruiné! rounds: 413
# vous avez gagné bravo! rounds: 121
# vous etes ruiné! rounds: 583
# vous etes ruiné! rounds: 97
# vous etes ruiné! rounds: 570
# vous etes ruiné! rounds: 828
# vous etes ruiné! rounds: 155
# vous etes ruiné! rounds: 182
# vous etes ruiné! rounds: 249
# vous avez gagné bravo! rounds: 112
# vous avez gagné bravo! rounds: 44
# vous etes ruiné! rounds: 362
# vous etes ruiné! rounds: 471
# vous etes ruiné! rounds: 534
# vous etes ruiné! rounds: 721
# vous etes ruiné! rounds: 565
# vous etes ruiné! rounds: 716
# vous etes ruiné! rounds: 428
# vous etes ruiné! rounds: 75
# vous etes ruiné! rounds: 713
# vous etes ruiné! rounds: 72
# vous etes ruiné! rounds: 660
# vous avez gagné bravo! rounds: 222
# vous etes ruiné! rounds: 4
# vous etes ruiné! rounds: 738
# vous etes ruiné! rounds: 20
# vous etes ruiné! rounds: 68
# vous etes ruiné! rounds: 454
# vous avez gagné bravo! rounds: 32
# vous etes ruiné! rounds: 405
# vous etes ruiné! rounds: 850
# vous etes ruiné! rounds: 1837
# vous etes ruiné! rounds: 990
# vous etes ruiné! rounds: 741
# vous etes ruiné! rounds: 170
# vous etes ruiné! rounds: 1238
# vous etes ruiné! rounds: 1870
# vous avez gagné bravo! rounds: 1044
# vous etes ruiné! rounds: 2
# vous etes ruiné! rounds: 693
# vous avez gagné bravo! rounds: 335
# vous etes ruiné! rounds: 46
# vous etes ruiné! rounds: 2588
# vous etes ruiné! rounds: 452
# vous avez gagné bravo! rounds: 145
# vous etes ruiné! rounds: 485
# vous etes ruiné! rounds: 995
# vous etes ruiné! rounds: 540
# vous etes ruiné! rounds: 859
# vous etes ruiné! rounds: 145
# vous etes ruiné! rounds: 1107
# vous etes ruiné! rounds: 142
# vous etes ruiné! rounds: 46
# vous etes ruiné! rounds: 854
# vous etes ruiné! rounds: 1343
# vous etes ruiné! rounds: 41
# vous etes ruiné! rounds: 1527
# vous etes ruiné! rounds: 476
# vous etes ruiné! rounds: 1048
# vous etes ruiné! rounds: 278
# vous etes ruiné! rounds: 32
# vous etes ruiné! rounds: 699
# vous etes ruiné! rounds: 718
# vous etes ruiné! rounds: 1415
# vous etes ruiné! rounds: 1004
# vous etes ruiné! rounds: 845
# vous etes ruiné! rounds: 556
# vous etes ruiné! rounds: 483
# vous etes ruiné! rounds: 143
# vous etes ruiné! rounds: 613
# vous avez gagné bravo! rounds: 1032
# vous avez gagné bravo! rounds: 81
# vous etes ruiné! rounds: 391
# vous avez gagné bravo! rounds: 63
# vous avez gagné bravo! rounds: 94
# vous etes ruiné! rounds: 19
# vous etes ruiné! rounds: 813
# vous etes ruiné! rounds: 670
# vous etes ruiné! rounds: 1623
# vous etes ruiné! rounds: 298
# vous etes ruiné! rounds: 2455
# vous etes ruiné! rounds: 1039
# vous etes ruiné! rounds: 199
# vous etes ruiné! rounds: 1035
# vous avez gagné bravo! rounds: 300
# vous avez gagné bravo! rounds: 38
# vous avez gagné bravo! rounds: 97
# vous etes ruiné! rounds: 424
# vous etes ruiné! rounds: 686
# vous avez gagné bravo! rounds: 36
# vous etes ruiné! rounds: 81
# vous etes ruiné! rounds: 88
# vous etes ruiné! rounds: 1491
# vous avez gagné bravo! rounds: 43
# vous etes ruiné! rounds: 983
# vous etes ruiné! rounds: 775
# vous avez gagné bravo! rounds: 151
# vous etes ruiné! rounds: 643
# vous etes ruiné! rounds: 391
# vous avez gagné bravo! rounds: 178
# vous etes ruiné! rounds: 176
# vous etes ruiné! rounds: 892
# vous etes ruiné! rounds: 1040
# vous etes ruiné! rounds: 1052
# vous etes ruiné! rounds: 130
# vous avez gagné bravo! rounds: 134
# vous etes ruiné! rounds: 349
# vous etes ruiné! rounds: 725
# vous etes ruiné! rounds: 408
# vous avez gagné bravo! rounds: 203
# vous etes ruiné! rounds: 1993
# vous etes ruiné! rounds: 987
# vous etes ruiné! rounds: 1854
# vous etes ruiné! rounds: 319
# vous avez gagné bravo! rounds: 82
# vous etes ruiné! rounds: 1519
# vous etes ruiné! rounds: 1152
# vous etes ruiné! rounds: 19
# vous avez gagné bravo! rounds: 912
# vous etes ruiné! rounds: 186
# vous etes ruiné! rounds: 74
# vous etes ruiné! rounds: 633
# vous avez gagné bravo! rounds: 156
# vous avez gagné bravo! rounds: 50
# vous etes ruiné! rounds: 947
# vous etes ruiné! rounds: 201
# vous avez gagné bravo! rounds: 371
# vous etes ruiné! rounds: 428
# vous etes ruiné! rounds: 351
# vous etes ruiné! rounds: 9
# vous etes ruiné! rounds: 283
# vous etes ruiné! rounds: 140
# vous etes ruiné! rounds: 122
# vous avez gagné bravo! rounds: 70
# vous etes ruiné! rounds: 910
# vous etes ruiné! rounds: 1627
# vous avez gagné bravo! rounds: 72
# vous etes ruiné! rounds: 845
# vous etes ruiné! rounds: 174
# vous etes ruiné! rounds: 1591
# vous etes ruiné! rounds: 2
# vous etes ruiné! rounds: 343
# vous etes ruiné! rounds: 832
# vous avez gagné bravo! rounds: 152
# vous etes ruiné! rounds: 1402
# vous etes ruiné! rounds: 194
# vous avez gagné bravo! rounds: 175
# vous etes ruiné! rounds: 154
# vous etes ruiné! rounds: 20
# vous avez gagné bravo! rounds: 117
# vous etes ruiné! rounds: 55
# vous etes ruiné! rounds: 176
# vous avez gagné bravo! rounds: 30
# vous etes ruiné! rounds: 142
# vous etes ruiné! rounds: 378
# vous etes ruiné! rounds: 88
# vous etes ruiné! rounds: 807
# vous etes ruiné! rounds: 499
# vous etes ruiné! rounds: 1294
# vous etes ruiné! rounds: 734
# vous etes ruiné! rounds: 183
# vous etes ruiné! rounds: 674
# vous avez gagné bravo! rounds: 45
# vous etes ruiné! rounds: 1386
# vous etes ruiné! rounds: 9
# vous etes ruiné! rounds: 379
# vous etes ruiné! rounds: 370
# vous etes ruiné! rounds: 935
# vous etes ruiné! rounds: 430
# vous etes ruiné! rounds: 127
# vous avez gagné bravo! rounds: 387
# vous avez gagné bravo! rounds: 95
# vous etes ruiné! rounds: 913
# vous avez gagné bravo! rounds: 118
# vous etes ruiné! rounds: 35
# vous etes ruiné! rounds: 963
# vous etes ruiné! rounds: 494
# vous etes ruiné! rounds: 677
# vous avez gagné bravo! rounds: 167
# vous etes ruiné! rounds: 1195
# vous avez gagné bravo! rounds: 185
# vous avez gagné bravo! rounds: 637
# vous avez gagné bravo! rounds: 92
# vous etes ruiné! rounds: 45
# vous etes ruiné! rounds: 88
# vous etes ruiné! rounds: 51
# vous etes ruiné! rounds: 278
# vous etes ruiné! rounds: 188
# vous etes ruiné! rounds: 943
# vous etes ruiné! rounds: 124
# vous etes ruiné! rounds: 936
# vous avez gagné bravo! rounds: 201
# vous avez gagné bravo! rounds: 23
# vous etes ruiné! rounds: 796
# vous etes ruiné! rounds: 799
# vous etes ruiné! rounds: 63
# vous etes ruiné! rounds: 452
# vous avez gagné bravo! rounds: 232
# probabilité approximative de gagner: 19 %
